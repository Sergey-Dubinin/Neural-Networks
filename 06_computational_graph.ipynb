# %%
import numpy as np
np.__version__

# %%
x = 5

w_0 = 1
w_1 = 2
w_2 = 3
w_3 = 4

# %%
f = w_0*w_2 + w_2*w_1*x + w_3

# %%
# w_2*w_1*x
c = w_2*w_1*x

# w_0*w_2
k = w_0*w_2

# w_0*w_2 + w_2*w_1*x + w_3
f = k + c + w_3
